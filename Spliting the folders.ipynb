# %%
import splitfolders

# Input folder (each class should have its own folder)
input_folder = r"C:\Users\HP\Contacts\OneDrive\Desktop\jupyter\Medicinal plant dataset"

# Just use ratio split
splitfolders.ratio(
    input_folder, 
    output="Data",    # New output folder
    seed=42, 
    ratio=(0.7, 0.2, 0.1),   # 70% train, 20% val, 10% test
    group_prefix=None
)

print("✅ Dataset splitting done successfully!")
# Out:
# Copying files: 0 files [00:00, ? files/s]
#
# Copying files: 29 files [00:00, 289.02 files/s]
#
# Copying files: 79 files [00:00, 410.31 files/s]
#
# Copying files: 130 files [00:00, 450.80 files/s]
#
# Copying files: 176 files [00:00, 452.22 files/s]
#
# Copying files: 222 files [00:00, 430.65 files/s]
#
# Copying files: 278 files [00:00, 472.17 files/s]
#
# Copying files: 330 files [00:00, 484.76 files/s]
#
# Copying files: 391 files [00:00, 522.12 files/s]
#
# Copying files: 448 files [00:00, 535.32 files/s]
#
# Copying files: 502 files [00:01, 520.44 files/s]
#
# Copying files: 562 files [00:01, 543.98 files/s]
#
# Copying files: 617 files [00:01, 544.08 files/s]
#
# Copying files: 677 files [00:01, 559.58 files/s]
#
# Copying files: 737 files [00:01, 571.05 files/s]
#
# Copying files: 795 files [00:01, 567.84 files/s]
#
# Copying files: 855 files [00:01, 576.07 files/s]
#
# Copying files: 913 files [00:01, 541.17 files/s]
#
# Copying files: 972 files [00:01, 553.96 files/s]
#
# ...
